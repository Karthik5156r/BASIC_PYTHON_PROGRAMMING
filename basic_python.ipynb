# %%
a=10
b="python"
c=10.5
d=2.14j
e=True
print("data type variable a:",type(a))
print("data type variable b:",type(b))
print("data type variable c:",type(c))
print("data type variable d:",type(d))
print("data type variable e:",type(e))
# Out:
# data type variable a: <class 'int'>
# data type variable b: <class 'str'>
# data type variable c: <class 'float'>
# data type variable d: <class 'complex'>
# data type variable e: <class 'bool'>

# %%
lst=["apple","orange","mango"]
print(lst)
lst.insert(1,"cherry")
print(lst)
lst.remove("mango")
print(lst)
lst.append("watermelon")
print(lst)
x=len(lst)
print(f"length of the list is {x}")
lst.pop()
print(lst)
lst.clear()
print(lst)
# Out:
# ['apple', 'orange', 'mango']
# ['apple', 'cherry', 'orange', 'mango']
# ['apple', 'cherry', 'orange']
# ['apple', 'cherry', 'orange', 'watermelon']
# length of the list is 4
# ['apple', 'cherry', 'orange']
# []

# %%
rainbow=('v','i','b','g','y','o','r')
print(rainbow)
colour=("red","green","blue")
res=rainbow+colour
print(res)
x=len(rainbow)
print("lenth of the tuple is",x)
y=input("enter the element to check:")
if y in rainbow:
    print(y,"is present in the tuple")
else:
    print(y,"is not present in the tuple")
print(rainbow[1])
# Out:
# ('v', 'i', 'b', 'g', 'y', 'o', 'r')
# ('v', 'i', 'b', 'g', 'y', 'o', 'r', 'red', 'green', 'blue')
# lenth of the tuple is 7
# enter the element to check: o
# o is present in the tuple
# i

# %%
college={"name":"rpa","code":"rp","pincode":560010}
print(college)
print(college.get("code"))
print(college.get("pincode"))
college["code"]="CA-2"
print(college)
x=len(college)
print(f"length of the given dictionary is {x}")
# Out:
# {'name': 'rpa', 'code': 'rp', 'pincode': 560010}
# rp
# 560010
# {'name': 'rpa', 'code': 'CA-2', 'pincode': 560010}
# length of the given dictionary is 3

# %%
def add(n1,n2):
    return n1+n2
def sub(n1,n2):
    return n1-n2
def mul(n1,n2):
    return n1*n2
def div(n1,n2):
    return n1/n2
print("welcome to arithmetic operation")
choice=1
while(choice!=0):
    x=int(input("enter the first number \n"))
    y=int(input("enter the second number\n"))
    print("1.to perform addition")
    print("2.to perform subtraction")
    print("3.to perform multiplication")
    print("4.to perform division")
    print("0.to exit")
    choice=int(input("enter your choice:"))
    if choice==1:
        print(x,"+",y,"=",add(x,y))
    elif choice==2:
        print(x,"-",y,"=",sub(x,y))
    elif choice==3:
        print(x,"*",y,"=",mul(x,y))
    elif choice==4:
        print(x,"/",y,"=",div(x,y))
    elif choice==0:
        print("exit")
    else:
        print("invalid choice")
# Out:
# welcome to arithmetic operation
# enter the first number
#  7
# enter the second number
#  7
# 1.to perform addition
# 2.to perform subtraction
# 3.to perform multiplication
# 4.to perform division
# 0.to exit
# enter your choice: 3
# 7 * 7 = 49
# enter the first number
#  0
# enter the second number
#  0
# 1.to perform addition
# 2.to perform subtraction
# 3.to perform multiplication
# 4.to perform division
# 0.to exit

# %%
n=int(input("enter the number :"))
if n>0:
    print(f"{n} is a positive number")
else:
    print(f"{n} is a negative number")
# Out:
# enter the number : 7
# 7 is a positive number

# %%
def find_even_number(listitems):
  print("the even numbers are:")
  for i in listitems:
    if i%2==0:
     print("\t\t\t\t",i)
def main():
        lst=[405,488,508,503,384]
        find_even_number(lst)
if __name__=="__main__":
        main()
# Out:
# the even numbers are:
# 				 488
# 				 508
# 				 384

# %%
import datetime
a=datetime.datetime.today()
b=datetime.datetime.now()
print(a)
print(b)
# Out:
# 2024-12-19 18:57:10.964073
# 2024-12-19 18:57:10.964072

# %%
from datetime import datetime
from datetime import timedelta
from datetime import date
begindatestring=date.today()
print("beginningdate")
print(begindatestring)
enddate=begindatestring+timedelta(days=10)
print("ending date")
print(enddate)
# Out:
# beginningdate
# 2024-12-19
# ending date
# 2024-12-29

# %%
def construct_character_dict(word):
    character_count_dict=dict()
    for each_character in word:
        character_count_dict[each_character]=character_count_dict.get(each_character,0)+1
        sorted_list_keys=sorted(character_count_dict.keys())
    for each_key in sorted_list_keys:
        print(each_key,character_count_dict.get(each_key))
def main():
    word=input("enter a string:")
    construct_character_dict(word)
if __name__=="__main__":
    main()
# Out:
# enter a string: karthik
# a 1
# h 1
# i 1
# k 2
# r 1
# t 1

# %%
def letter_frequency(filename,letter):
    file=open(filename,'r')
    text=file.read()
    return text.count(letter)
print(f"the letter appears {letter_frequency('sample.txt','i')} times in a given file")
# Out:
# the letter appears 3 times in a given file

# %%
import numpy as np
arr=np.array([[1,2,3],[4,2,5]])
print("array is of type:",type(arr))
print("number of dimensions:",arr.ndim)
print("shape of array:",arr.shape)
print("size of array:",arr.size)
print("array stores elements of type:",arr.dtype)
# Out:
# array is of type: <class 'numpy.ndarray'>
# number of dimensions: 2
# shape of array: (2, 3)
# size of array: 6
# array stores elements of type: int64

# %%
import pandas as pd
one=pd.DataFrame({'name':['karthik','jeeva'],'age':[19,20]},index=[1,2])
two=pd.DataFrame({'name':['santhosh','yogesh'],'age':[19,20]},index=[3,4])
print(pd.concat([one,two]))
# Out:
#        name  age
# 1   karthik   19
# 2     jeeva   20
# 3  santhosh   19
# 4    yogesh   20

# %%
import pandas as pd
print("read the csv file")
r=pd.read_csv("data1.csv")
print(r)
print("*********************")
print("\n reading csv file with first 5 rows and the last 5 rows")
r=pd.read_csv("data1.csv",skiprows=[6,7])
print(r)
# Out:
# read the csv file
#     month    pen   book  marker  chair  table  pen stand  total unit  \
# 0       1   3954  11773    9170   8960   8560       6704       49121
# 1       2   3603  11897    9416   6204   7297       9981       48398
# 2       3   9704  10111    8522   7229  10405      10280       56251
# 3       4   3492   2525   10572   9802   7674       3100       37165
# 4       5   8497   7201    3808   9000   4289       4413       37208
# 5       6  10356   3424    3198   8788   9141       9654       44561
# 6       7   8156   2448    6747   9046   8320      11969       46686
# 7       8   3919  10883    7403   8690   2510       7109       40514
# 8       9   4942   5157    6195  11665   9728       4151       41838
# 9      10   8296   8218    7242  11837  10823       3318       49734
# 10     11   6190  10317    2634   6147   4403      11647       41338
# 11     12   4488   8551    7658  11915   7219       5981       45812
#
#     total profit
# 0         491210
# ...

# %%
import math as m
radius=float(input("enter the radius of the circle:"))
area=m.pi*radius*radius
circum=2*m.pi*radius
print("the area of circle is:",area)
print("the circumference of circle is:",circum)
# Out:
# enter the radius of the circle: 5
# the area of circle is: 78.53981633974483
# the circumference of circle is: 31.41592653589793

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("data1.csv")
plist=df["total profit"].tolist()
mlist=df["month"].tolist()
plt.plot(mlist,plist,label='profit data list',linestyle='--',color='b',linewidth=4)
plt.xlabel("month")
plt.ylabel("total profit")
plt.legend(loc="lower right")
plt.xticks(mlist)
plt.yticks([100000,200000,300000,400000,500000])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv("data1.csv")
print(df1)
plt.style.use("ggplot")
df1.plot.line()
plt.show()
# Out:
#     month    pen   book  marker  chair  table  pen stand  total unit  \
# 0       1   3954  11773    9170   8960   8560       6704       49121
# 1       2   3603  11897    9416   6204   7297       9981       48398
# 2       3   9704  10111    8522   7229  10405      10280       56251
# 3       4   3492   2525   10572   9802   7674       3100       37165
# 4       5   8497   7201    3808   9000   4289       4413       37208
# 5       6  10356   3424    3198   8788   9141       9654       44561
# 6       7   8156   2448    6747   9046   8320      11969       46686
# 7       8   3919  10883    7403   8690   2510       7109       40514
# 8       9   4942   5157    6195  11665   9728       4151       41838
# 9      10   8296   8218    7242  11837  10823       3318       49734
# 10     11   6190  10317    2634   6147   4403      11647       41338
# 11     12   4488   8551    7658  11915   7219       5981       45812
#
#     total profit
# 0         491210
# 1         483980
# ...

# %%
def f(word):
    v=dict()
    for v1 in word:
        v[v1]=v.get(v1,0)+1
        s=sorted(v.keys())
    for v2 in s:
        print(v2,v.get(v2))
def main():
    word=input("enter a string:")
    f(word)
if __name__=="__main__":
    main()
# Out:
# enter a string: karthik
# a 1
# h 1
# i 1
# k 2
# r 1
# t 1

# %%
def f(a,b):
    file=open(a,'r')
    text=file.read()
    return text.count(b)
print(f"the letter appears {f('sample.txt','i')} times in a given file")
# Out:
# the letter appears 3 times in a given file
